# %% [markdown]
# # 第1章: 準備運動
# ## 00. 文字列の逆順
# 文字列"stressed"の文字を逆に（末尾から先頭に向かって）並べた文字列を得よ．

# %%
s = 'stressed'
print s[1:7:2]  # from 1 to 7-1 step 2
print s[::-1]
# Out:
# tes
# desserts

# %% [markdown]
# ## 01. 「パタトクカシーー」
# 「パタトクカシーー」という文字列の1,3,5,7文字目を取り出して連結した文字列を得よ．

# %%
s = u'パタトクカシーー'
print s[1:8:2]
# Out:
# タクシー

# %% [markdown]
# ## 02. 「パトカー」＋「タクシー」＝「パタトクカシーー」
# 「パトカー」＋「タクシー」の文字を先頭から交互に連結して文字列「パタトクカシーー」を得よ．

# %%
s = u'パトカー'
t = u'タクシー'
print ''.join(si + ti for si, ti in zip(s, t))
# Out:
# パタトクカシーー

# %%
print [si + ti for si, ti in zip(s, t)]  # list
print (si + ti for si, ti in zip(s, t))  # generator
# Out:
# [u'\u30d1\u30bf', u'\u30c8\u30af', u'\u30ab\u30b7', u'\u30fc\u30fc']
# <generator object <genexpr> at 0x0000000003FA4288>

# %%
print sum(xrange(100000000))
# Out:
# 4999999950000000

# %% [markdown]
# ## 03. 円周率
# "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."という文を単語に分解し，各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成せよ．

# %%
s = 'Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.'
print s.replace('.', '').replace(',', '')
print [len(word) for word in s.replace('.', '').replace(',', '').split()]
import math
print math.pi
# Out:
# Now I need a drink alcoholic of course after the heavy lectures involving quantum mechanics
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]
# 3.14159265359

# %% [markdown]
# ## 04. 元素記号
# "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."という文を単語に分解し，1, 5, 6, 7, 8, 9, 15, 16, 19番目の単語は先頭の1文字，それ以外の単語は先頭に2文字を取り出し，取り出した文字列から単語の位置（先頭から何番目の単語か）への連想配列（辞書型もしくはマップ型）を作成せよ．

# %%
s = 'Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.'
print s.split()
singles = [1, 5, 6, 7, 8, 9, 15, 16, 19]
print [symbol[0] if i in singles else symbol[:2]
       for i, symbol in enumerate(s.split(), 1)]
print {(symbol[0] if i in singles else symbol[:2]): i  # key: value
       for i, symbol in enumerate(s.split(), 1)}
# Out:
# ['Hi', 'He', 'Lied', 'Because', 'Boron', 'Could', 'Not', 'Oxidize', 'Fluorine.', 'New', 'Nations', 'Might', 'Also', 'Sign', 'Peace', 'Security', 'Clause.', 'Arthur', 'King', 'Can.']
# ['H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne', 'Na', 'Mi', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar', 'K', 'Ca']
# {'Be': 4, 'C': 6, 'B': 5, 'Ca': 20, 'F': 9, 'S': 16, 'H': 1, 'K': 19, 'Al': 13, 'Mi': 12, 'Ne': 10, 'O': 8, 'Li': 3, 'P': 15, 'Si': 14, 'Ar': 18, 'Na': 11, 'N': 7, 'Cl': 17, 'He': 2}

# %%
abc = ['a', 'b', 'c']
print list(enumerate(abc))
print list(enumerate(abc, 1))
x = 1
print 'One' if x == 1 else 'Not one'
x = 0
print 'One' if x == 1 else 'Not one'
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]
# [(1, 'a'), (2, 'b'), (3, 'c')]
# One
# Not one

# %% [markdown]
# ## 05. n-gram
# 与えられたシーケンス（文字列やリストなど）からn-gramを作る関数を作成せよ．この関数を用い，"I am an NLPer"という文から単語bi-gram，文字bi-gramを得よ．

# %%
def ngram(seq, n=2):  # n が指定されていないときには、デフォルト値 2
    # [[seq[0], seq[1],..., seq[n-1]],  => seq[0:n]
    #  [seq[1], seq[2],..., seq[n]],    => seq[1:n+1]
    #  ...]
    return [seq[i:i+n] for i in range(len(seq) - n + 1)]

s = 'I am an NLPer'
print ngram(s.split())
print ngram(s)
# Out:
# [['I', 'am'], ['am', 'an'], ['an', 'NLPer']]
# ['I ', ' a', 'am', 'm ', ' a', 'an', 'n ', ' N', 'NL', 'LP', 'Pe', 'er']

# %% [markdown]
# ## 06. 集合
# "paraparaparadise"と"paragraph"に含まれる文字bi-gramの集合を，それぞれ, XとYとして求め，XとYの和集合，積集合，差集合を求めよ．さらに，'se'というbi-gramがXおよびYに含まれるかどうかを調べよ．

# %%
print set([1, 2, 2])
print {1, 2, 2}
X = set(ngram('paraparaparadise'))
Y = set(ngram('paragraph'))
print Y
# print dir(X)
print X.union(Y)
print X | Y  # 上と同じ意味
print X.intersection(Y)
print X & Y  # 上と同じ意味
print X.difference(Y)
print X - Y  # 上と同じ意味
print 'se' in X, 'se' in Y
# Out:
# set([1, 2])
# set([1, 2])
# set(['gr', 'ag', 'ap', 'pa', 'ra', 'ph', 'ar'])
# set(['ad', 'ag', 'di', 'is', 'ap', 'pa', 'ra', 'ph', 'ar', 'se', 'gr'])
# set(['ad', 'ag', 'di', 'is', 'ap', 'pa', 'ra', 'ph', 'ar', 'se', 'gr'])
# set(['ap', 'pa', 'ar', 'ra'])
# set(['ap', 'pa', 'ar', 'ra'])
# set(['is', 'ad', 'se', 'di'])
# set(['is', 'ad', 'se', 'di'])
# True False

# %% [markdown]
# ## 07. テンプレートによる文生成
# 引数x, y, zを受け取り「x時のyはz」という文字列を返す関数を実装せよ．さらに，x=12, y="気温", z=22.4として，実行結果を確認せよ．

# %%
def old_fashioned(x, y, z):
    return u'%s時の%sは%s' % (x, y, z)  # printf("%s時の%sは%s", x, y, z)

def modern(x, y, z):
    return u'{hour}時の{metric}は{value}'.format(hour=x, metric=y, value=z)

print old_fashioned(12, u'気温', 22.4)
print modern(12, u'気温', 22.4)
# Out:
# 12時の気温は22.4
# 12時の気温は22.4

# %% [markdown]
# ## 08. 暗号文
# 与えられた文字列の各文字を，以下の仕様で変換する関数cipherを実装せよ．
#
# 英小文字ならば(219 - 文字コード)の文字に置換
# その他の文字はそのまま出力
# この関数を用い，英語のメッセージを暗号化・復号化せよ．

# %%
import string
print string.lowercase
print ord('a')
print chr(97)

def cipher(cs):
    return ''.join(chr(219 - ord(c)) if c in string.lowercase else c for c in cs)

def decipher(cs):
    # homework!
    pass
    
print cipher('This is a pen.')
# Out:
# abcdefghijklmnopqrstuvwxyz
# 97
# a
# Tsrh rh z kvm.

# %% [markdown]
# ## 09. Typoglycemia
# スペースで区切られた単語列に対して，各単語の先頭と末尾の文字は残し，それ以外の文字の順序をランダムに並び替えるプログラムを作成せよ．ただし，長さが４以下の単語は並び替えないこととする．適当な英語の文（例えば"I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."）を与え，その実行結果を確認せよ．

# %%
import random
s = 'abcdef'
print s[1:-1]

def shuffle(word):
    middle = list(word[1:-1])  # 入力が 'abcdef' なら middle = ['b', 'c', 'd', 'e']
    random.shuffle(middle)
    return ''.join([word[0]] + middle + [word[-1]])

print shuffle(s)
text = "I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."
print ' '.join(word if len(word) <= 4 else shuffle(word)
               for word in text.split())

# 同じことをもう少しわかりやすく書くと...
words = []
for word in text.split():
    if len(word) <= 4:
        words.append(word)
    else:
        words.append(shuffle(word))
print ' '.join(words)
# Out:
# bcde
# adcebf
# I co'nudlt bleivee that I cluod atcaluly utdesrnnad what I was rdeniag : the pneohmnael power of the huamn mind .
# I culodn't biveele that I culod acalluty unsdntaerd what I was redniag : the pomnheenal pwoer of the human mind .
